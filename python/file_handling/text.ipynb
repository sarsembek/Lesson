# %%
f = open("demo.txt", "r")
for x in f:
  print(x)
# Out:
# Hello World!
#
# QIT 23-9

# %%
f = open("demo1.txt", "a")
f.write("Now the file has more content!")
f.close()

f = open("demo1.txt", "r")
print(f.read())
# Out:
# Now the file has more content!

# %%
f = open("demo3.txt", "a")
f.write("\nWoops! I have deleted the content!")
f.close()

#open and read the file after the overwriting:
f = open("demo3.txt", "r")
print(f.read())
# Out:
# Woops! I have deleted the content!Woops! I have deleted the content!Woops! I have deleted the content!Woops! I have deleted the content!
# Woops! I have deleted the content!
# Woops! I have deleted the content!
# Woops! I have deleted the content!

# %%
import os
os.remove("demo3.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\777\Desktop\Lesson\python\file_handling\text.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/777/Desktop/Lesson/python/file_handling/text.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/777/Desktop/Lesson/python/file_handling/text.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> os.remove("demo3.txt")
#
# PermissionError: [WinError 32] Процесс не может получить доступ к файлу, так как этот файл занят другим процессом: 'demo3.txt'

# %%
import os
if os.path.exists("demo3.txt"):
  print("The file exist")
else:
  print("The file does not exist")
# Out:
# The file does not exist

# %%
import os
os.rmdir("../../html&css/udalit")
